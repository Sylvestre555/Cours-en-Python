# %%
# Importation de package pandas
import pandas as pd

# %%
df=pd.read_csv("Extended_Employee_Performance_and_Productivity.csv",sep=";")
df
# Out:
#        Employee_ID        Department  Gender  Age   Job_Title   Hire_Date  \
# 0                1                IT    Male   55  Specialist  19/01/2022
# 1                2           Finance    Male   29   Developer  18/04/2024
# 2                3           Finance    Male   55  Specialist  26/10/2015
# 3                4  Customer Support  Female   48     Analyst  22/10/2016
# 4                5       Engineering  Female   36     Analyst  23/07/2021
# ...            ...               ...     ...  ...         ...         ...
# 99995        99996           Finance    Male   27  Technician  07/12/2022
# 99996        99997                IT  Female   36  Consultant  24/07/2018
# 99997        99998        Operations    Male   53     Analyst  24/11/2015
# 99998        99999                HR  Female   22  Consultant  03/08/2015
# 99999       100000           Finance  Female   43     Analyst  04/03/2024
#
#       Education_Level Performance_Score  Salary_month   Work_Hours_Per_Week  \
# ...

# %%
df.head()
# Out:
#    Employee_ID        Department  Gender  Age   Job_Title   Hire_Date  \
# 0            1                IT    Male   55  Specialist  19/01/2022
# 1            2           Finance    Male   29   Developer  18/04/2024
# 2            3           Finance    Male   55  Specialist  26/10/2015
# 3            4  Customer Support  Female   48     Analyst  22/10/2016
# 4            5       Engineering  Female   36     Analyst  23/07/2021
#
#   Education_Level Performance_Score  Salary_month   Work_Hours_Per_Week  \
# 0     High School     Very satisied        6750,00                   33
# 1     High School     Very satisied        7500,00                   34
# 2     High School        acceptable        5850,00                   37
# 3        Bachelor             lower        4800,00                   52
# 4        Bachelor             lower        4800,00                   38
#
#    Projects_Handled  Overtime_Hours  Sick_Days  Remote_Work_Frequency  \
# ...

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Department', 'Gender', 'Age', 'Job_Title', 'Hire_Date',
#        'Education_Level', 'Performance_Score', ' Salary_month ',
#        'Work_Hours_Per_Week', 'Projects_Handled', 'Overtime_Hours',
#        'Sick_Days', 'Remote_Work_Frequency', 'Training_Hours', 'Promotions',
#        'Employee_Satisfaction_Score', 'Resigned'],
#       dtype='object')

# %%
df.shape
# Out:
# (100000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Employee_ID                  100000 non-null  int64
#  1   Department                   100000 non-null  object
#  2   Gender                       100000 non-null  object
#  3   Age                          100000 non-null  int64
#  4   Job_Title                    100000 non-null  object
#  5   Hire_Date                    100000 non-null  object
#  6   Education_Level              100000 non-null  object
#  7   Performance_Score            100000 non-null  object
#  8    Salary_month                100000 non-null  object
#  9   Work_Hours_Per_Week          100000 non-null  int64
#  10  Projects_Handled             100000 non-null  int64
#  11  Overtime_Hours               100000 non-null  int64
# ...

# %%
df.isna()
# Out:
#        Employee_ID  Department  Gender    Age  Job_Title  Hire_Date  \
# 0            False       False   False  False      False      False
# 1            False       False   False  False      False      False
# 2            False       False   False  False      False      False
# 3            False       False   False  False      False      False
# 4            False       False   False  False      False      False
# ...            ...         ...     ...    ...        ...        ...
# 99995        False       False   False  False      False      False
# 99996        False       False   False  False      False      False
# 99997        False       False   False  False      False      False
# 99998        False       False   False  False      False      False
# 99999        False       False   False  False      False      False
#
#        Education_Level  Performance_Score   Salary_month   \
# 0                False              False           False
# ...

# %%
df.describe()
# Out:
#          Employee_ID            Age  Work_Hours_Per_Week  Projects_Handled  \
# count  100000.000000  100000.000000        100000.000000     100000.000000
# mean    50000.500000      41.029410            44.956950         24.431170
# std     28867.657797      11.244121             8.942003         14.469584
# min         1.000000      22.000000            30.000000          0.000000
# 25%     25000.750000      31.000000            37.000000         12.000000
# 50%     50000.500000      41.000000            45.000000         24.000000
# 75%     75000.250000      51.000000            53.000000         37.000000
# max    100000.000000      60.000000            60.000000         49.000000
#
#        Overtime_Hours      Sick_Days  Remote_Work_Frequency  Training_Hours  \
# count   100000.000000  100000.000000          100000.000000   100000.000000
# mean        14.514930       7.008550              50.090500       49.506060
# ...

# %% [markdown]
# ##  Est ce que les niveaux_d'études des employés peuvent influencer sur le salaire mensuel .

# %%
df["Education_Level"].unique()
# Out:
# array(['High School', 'Bachelor', 'Master', 'PhD'], dtype=object)

# %%
df["Education_Level"].value_counts()
# Out:
# Education_Level
# Bachelor       50041
# High School    30004
# Master         14904
# PhD             5051
# Name: count, dtype: int64

# %%
df["Education_Level"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Education_Level'>

# %%
df["Resigned"]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996     True
# 99997    False
# 99998    False
# 99999    False
# Name: Resigned, Length: 100000, dtype: bool

# %%
df["Resigned"].value_counts(normalize=True)*100
# Out:
# Resigned
# False    89.99
# True     10.01
# Name: proportion, dtype: float64

# %%
df["Resigned"].value_counts(normalize=True).plot(kind="bar")

# %%
table_contegence=pd.crosstab(df["Education_Level"],df["Resigned"])

# %%
table_contegence

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
if sns:
    plt.figure()
    sns.countplot(x="Education_Level", hue="Resigned", data=df)
    plt.title("Countplot — retour produit par sexe")
    plt.show()

# %%
    plt.figure()
    sns.heatmap(table_contegence, annot=True, fmt="d", cmap="Blues")
    plt.title("Heatmap — table_contegence")
    plt.show()

# %%
df.columns

# %%
df.groupby("Gender")["Age"].agg(
    moyenne = "mean",
    mediane = "median",
    variance = "var",
    ecart_type = "std",
    minimum = "min",
    Q1 = lambda x: x.quantile(0.25),
    Q2 = "median",
    Q3 = lambda x: x.quantile(0.75),
    maximum = "max",
    IQR = lambda x: x.quantile(0.75) - x.quantile(0.25),
    etendue = lambda x: x.max() - x.min()
)

# %%
df.columns

# %%
df.dtypes

# %%
df["Age"].unique()
# Out:
# array([55, 29, 48, 36, 43, 37, 45, 52, 27, 51, 46, 26, 28, 56, 23, 33, 59,
#        58, 38, 53, 24, 25, 41, 42, 44, 60, 32, 31, 40, 57, 35, 34, 54, 49,
#        39, 47, 50, 30, 22])

# %%
df["Age"].describe()

# %%
df["Age"].plot(kind="bar")

# %%
### ⚙️Calculs en Python

mean_value = Age.mean()
median_value = Age.median()
mode_values = donnée.mode()  
# peut retourner plusieurs valeurs

print(f"Moyenne : {Age:.2f}")
print(f"Médiane : {Age:.2f}")
print("Mode(s) :")
print(mode_values)

# %% [markdown]
# ## Interprétation :
# Si la moyenne et la médiane sont proches, la distribution est souvent relativement symétrique.
#
# Si la moyenne est nettement > médiane → asymétrie à droite (queue à droite).
#
# Si la moyenne est nettement < médiane → asymétrie à gauche.

# %% [markdown]
# ## Nous remarquons la moyenne et la mediane ont une distribution relativement symetrique car la moyenne est proche de mediane

# %% [markdown]
# ## Visualisations (histogramme, KDE, boxplot)
#
#  Les graphiques permettent de voir la distribution :
#
# Histogramme : fréquence des valeurs dans des classes ;
#
# KDE (Kernel Density Estimation) : estimation lissée de la densité ;
#
# Boxplot : résumé visuel (médiane, quartiles, outliers).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df["Age"])
