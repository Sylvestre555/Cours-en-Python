# %% [markdown]
# **Projet 2**

# %% [markdown]
# **Objectif**

# %% [markdown]
# Analyser les relations entre les variables qualitatives-qualitatives qualitatives-quantitative et quantitatives-quantitatives
# pour detecter des facteurs clés

# %%
#importation de pandas et les données

# %%
import pandas as pd

# %%
df=pd.read_csv("Sample - Superstore1.csv",encoding='latin-1',sep=";")
df
# Out:
#       Row ID        Order ID       Ship Mode Customer ID     Customer Name  \
# 0          1  CA-2016-152156    Second Class    CG-12520       Claire Gute
# 1          2  CA-2016-152156    Second Class    CG-12520       Claire Gute
# 2          3  CA-2016-138688    Second Class    DV-13045   Darrin Van Huff
# 3          4  US-2015-108966  Standard Class    SO-20335    Sean O'Donnell
# 4          5  US-2015-108966  Standard Class    SO-20335    Sean O'Donnell
# ...      ...             ...             ...         ...               ...
# 9989    9990  CA-2014-110422    Second Class    TB-21400  Tom Boeckenhauer
# 9990    9991  CA-2017-121258  Standard Class    DB-13060       Dave Brooks
# 9991    9992  CA-2017-121258  Standard Class    DB-13060       Dave Brooks
# 9992    9993  CA-2017-121258  Standard Class    DB-13060       Dave Brooks
# 9993    9994  CA-2017-119914    Second Class    CC-12220      Chris Cortes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Ship Mode      9994 non-null   object
#  3   Customer ID    9994 non-null   object
#  4   Customer Name  9994 non-null   object
#  5   Segment        9994 non-null   object
#  6   Country        9994 non-null   object
#  7   City           9994 non-null   object
#  8   State          9994 non-null   object
#  9   Postal Code    9994 non-null   int64
#  10  Region         9994 non-null   object
#  11  Product ID     9994 non-null   object
#  12  Category       9994 non-null   object
#  13  Sub-Category   9994 non-null   object
#  14  Product Name   9994 non-null   object
#  15  Sales          9988 non-null   object
#  16  Quantity       9988 non-null   float64
# ...

# %%
df
# Out:
#       Row ID        Order ID       Ship Mode Customer ID     Customer Name  \
# 0          1  CA-2016-152156    Second Class    CG-12520       Claire Gute
# 1          2  CA-2016-152156    Second Class    CG-12520       Claire Gute
# 2          3  CA-2016-138688    Second Class    DV-13045   Darrin Van Huff
# 3          4  US-2015-108966  Standard Class    SO-20335    Sean O'Donnell
# 4          5  US-2015-108966  Standard Class    SO-20335    Sean O'Donnell
# ...      ...             ...             ...         ...               ...
# 9989    9990  CA-2014-110422    Second Class    TB-21400  Tom Boeckenhauer
# 9990    9991  CA-2017-121258  Standard Class    DB-13060       Dave Brooks
# 9991    9992  CA-2017-121258  Standard Class    DB-13060       Dave Brooks
# 9992    9993  CA-2017-121258  Standard Class    DB-13060       Dave Brooks
# 9993    9994  CA-2017-119914    Second Class    CC-12220      Chris Cortes
#
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code     Quantity
# count  9994.000000   9994.000000  9988.000000
# mean   4997.500000  55190.379428     3.788646
# std    2885.163629  32063.693350     2.224976
# min       1.000000   1040.000000     1.000000
# 25%    2499.250000  23223.000000     2.000000
# 50%    4997.500000  56430.500000     3.000000
# 75%    7495.750000  90008.000000     5.000000
# max    9994.000000  99301.000000    14.000000

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Ship Mode', 'Customer ID', 'Customer Name',
#        'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Ship Mode      9994 non-null   object
#  3   Customer ID    9994 non-null   object
#  4   Customer Name  9994 non-null   object
#  5   Segment        9994 non-null   object
#  6   Country        9994 non-null   object
#  7   City           9994 non-null   object
#  8   State          9994 non-null   object
#  9   Postal Code    9994 non-null   int64
#  10  Region         9994 non-null   object
#  11  Product ID     9994 non-null   object
#  12  Category       9994 non-null   object
#  13  Sub-Category   9994 non-null   object
#  14  Product Name   9994 non-null   object
#  15  Sales          9988 non-null   object
#  16  Quantity       9988 non-null   float64
# ...

# %%
table=pd.crosstab(df["Region"],df["Category"])

# %%
table
# Out:
# Category  Furniture  Office Supplies  Technology
# Region
# Central         481             1422         420
# East            601             1712         535
# South           332              995         293
# West            707             1897         599

# %%
matrice_corr=table.corr()

# %%
matrice_corr
# Out:
# Category         Furniture  Office Supplies  Technology
# Category
# Furniture         1.000000         0.994841    0.997073
# Office Supplies   0.994841         1.000000    0.997923
# Technology        0.997073         0.997923    1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
   if sns:
    plt.figure()
    sns.countplot(x="Category", hue="Region", data=df)
    plt.title("Countplot — retour produit par sexe")
    plt.show()

    plt.figure()
    sns.heatmap(table, annot=True, fmt="d", cmap="Blues")
    plt.title("Heatmap — table de contingence")
    plt.show()

# %%
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Ship Mode      9994 non-null   object
#  3   Customer ID    9994 non-null   object
#  4   Customer Name  9994 non-null   object
#  5   Segment        9994 non-null   object
#  6   Country        9994 non-null   object
#  7   City           9994 non-null   object
#  8   State          9994 non-null   object
#  9   Postal Code    9994 non-null   int64
#  10  Region         9994 non-null   object
#  11  Product ID     9994 non-null   object
#  12  Category       9994 non-null   object
#  13  Sub-Category   9994 non-null   object
#  14  Product Name   9994 non-null   object
#  15  Sales          9988 non-null   object
#  16  Quantity       9988 non-null   float64
# ...

# %%
df["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df["Region"].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df["Region"].value_counts()/len(df["Region"])
# Out:
# Region
# West       0.320492
# East       0.284971
# Central    0.232439
# South      0.162097
# Name: count, dtype: float64

# %%
df["Region"].value_counts()/len(df["Region"])
# Out:
# Region
# West       0.320492
# East       0.284971
# Central    0.232439
# South      0.162097
# Name: count, dtype: float64

# %%
df["Region"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Region'>

# %%
df["Region"].value_counts().plot(kind="bar",color = ["blue", "red", "green", "purple"])
# Out:
# <Axes: xlabel='Region'>

# %%
effectif = effectif["Country"].value_counts().reset_index()
effectif["proportion"] = effectif["count"]/effectif["count"].sum()
effectif["proportion"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 effectif = effectif["Country"].value_counts().reset_index()
# ...

# %%
plt.bar(effectif["Country"], effectif["proportion"], color = ["blue", "red", "green", "purple"])
plt.title("Répartition par niveau d'éducation")
plt.xlabel("Catégorie")
plt.ylabel("Proportion")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ...
